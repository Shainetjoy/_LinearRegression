# %% [markdown]
# ###LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
D1 = pd.read_csv('/content/drive/MyDrive/youtube data/canada_per_capita_income.csv')

# %%
D1
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
x =D1['year']
x
# Out:
# 0     1970
# 1     1971
# 2     1972
# 3     1973
# 4     1974
# 5     1975
# 6     1976
# 7     1977
# 8     1978
# 9     1979
# 10    1980
# 11    1981
# 12    1982
# 13    1983
# 14    1984
# 15    1985
# 16    1986
# 17    1987
# 18    1988
# 19    1989
# 20    1990
# 21    1991
# 22    1992
# 23    1993
# 24    1994
# 25    1995
# 26    1996
# 27    1997
# 28    1998
# 29    1999
# 30    2000
# 31    2001
# 32    2002
# 33    2003
# 34    2004
# 35    2005
# 36    2006
# 37    2007
# 38    2008
# 39    2009
# 40    2010
# 41    2011
# 42    2012
# 43    2013
# 44    2014
# 45    2015
# 46    2016
# Name: year, dtype: int64

# %%
x=D1[['year']]
y=D1['per capita income (US$)']

# %%
x.shape

# %%
y.shape
# Out:
# (47,)

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[2020]])
print(prediction)
# Out:
# [41288.69409442]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model.save('Linear_Model.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-337232859e14> in <cell line: 1>()
# ----> 1 model.save('Linear_Model.h5')
#
# AttributeError: 'LinearRegression' object has no attribute 'save'

# %% [markdown]
# ##multiple-linear-regression-model

# %%
import numpy as np
import matplotlib.pyplot as mtp
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv('/content/multiple_linear_regression_dataset.csv')

# %%
df
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
x = df.drop('income',axis = 1)
y = df["income"]

# %%
x
# Out:
#     age  experience
# 0    25           1
# 1    30           3
# 2    47           2
# 3    32           5
# 4    43          10
# 5    51           7
# 6    28           5
# 7    33           4
# 8    37           5
# 9    39           8
# 10   29           1
# 11   47           9
# 12   54           5
# 13   51           4
# 14   44          12
# 15   41           6
# 16   58          17
# 17   23           1
# 18   44           9
# 19   37          10

# %%
y
# Out:
# 0     30450
# 1     35670
# 2     31580
# 3     40130
# 4     47830
# 5     41630
# 6     41340
# 7     37650
# 8     40250
# 9     45150
# 10    27840
# 11    46110
# 12    36720
# 13    34800
# 14    51300
# 15    38900
# 16    63600
# 17    30870
# 18    44190
# 19    48700
# Name: income, dtype: int64

# %%
mmax = MinMaxScaler()

# %%
x=pd.DataFrame(mmax.fit_transform(x),columns=x.columns)
x
# Out:
#          age  experience
# 0   0.057143      0.0000
# 1   0.200000      0.1250
# 2   0.685714      0.0625
# 3   0.257143      0.2500
# 4   0.571429      0.5625
# 5   0.800000      0.3750
# 6   0.142857      0.2500
# 7   0.285714      0.1875
# 8   0.400000      0.2500
# 9   0.457143      0.4375
# 10  0.171429      0.0000
# 11  0.685714      0.5000
# 12  0.885714      0.2500
# 13  0.800000      0.1875
# 14  0.600000      0.6875
# 15  0.514286      0.3125
# 16  1.000000      1.0000
# 17  0.000000      0.0000
# 18  0.600000      0.5000
# 19  0.400000      0.5625

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
print(xtrain)
# Out:
#          age  experience
# 11  0.685714      0.5000
# 3   0.257143      0.2500
# 18  0.600000      0.5000
# 16  1.000000      1.0000
# 13  0.800000      0.1875
# 2   0.685714      0.0625
# 9   0.457143      0.4375
# 19  0.400000      0.5625
# 4   0.571429      0.5625
# 12  0.885714      0.2500
# 7   0.285714      0.1875
# 10  0.171429      0.0000
# 14  0.600000      0.6875
# 6   0.142857      0.2500 11    46110
# 3     40130
# 18    44190
# 16    63600
# 13    34800
# 2     31580
# 9     45150
# 19    48700
# 4     47830
# 12    36720
# 7     37650
# 10    27840
# 14    51300
# 6     41340
# Name: income, dtype: int64

# %%
print(ytrain)
# Out:
# 11    46110
# 3     40130
# 18    44190
# 16    63600
# 13    34800
# 2     31580
# 9     45150
# 19    48700
# 4     47830
# 12    36720
# 7     37650
# 10    27840
# 14    51300
# 6     41340
# Name: income, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(xtest)

# %%
y_pred
# Out:
# array([30822.32314416, 31019.01707419, 40089.99927433, 34667.07934725,
#        38315.14162031, 41274.77513825])

# %%
mse = mean_squared_error(ytest,y_pred)

# %%
mse
# Out:
# 1075440.0620919282

# %%
r2 =r2_score(ytest,y_pred)

# %%
r2
# Out:
# 0.9438292972477471
